# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/Nameet/Downloads/train.csv")

# %%
df.head()
# Out:
#    profile_pic  nums_length_of_username  fullname_words  nums_length_fullname  \
# 0            1                     0.27               0                   0.0
# 1            1                     0.00               2                   0.0
# 2            1                     0.10               2                   0.0
# 3            1                     0.00               1                   0.0
# 4            1                     0.00               2                   0.0
#
#    name_username  description_length  external_URL  private  no_of_posts  \
# 0              0                  53             0        0           32
# 1              0                  44             0        0          286
# 2              0                   0             0        1           13
# 3              0                  82             0        0          679
# 4              0                   0             0        1            6
#
#    no_of_followers  no_of_following  fake
# 0             1000              955     0
# 1             2740              533     0
# 2              159               98     0
# 3              414              651     0
# 4              151              126     0

# %%
df.corr()
# Out:
#                          profile_pic  nums_length_of_username  fullname_words  \
# profile_pic                 1.000000                -0.364087        0.213295
# nums_length_of_username    -0.364087                 1.000000       -0.225472
# fullname_words              0.213295                -0.225472        1.000000
# nums_length_fullname       -0.131756                 0.408567       -0.094348
# name_username              -0.124903                 0.056890       -0.082969
# description_length          0.367892                -0.321170        0.272522
# external_URL                0.236729                -0.237125        0.196562
# private                     0.114732                -0.063713       -0.089070
# no_of_posts                 0.169570                -0.157442        0.073350
# no_of_followers             0.061137                -0.062785        0.033225
# no_of_following             0.194833                -0.172413        0.094855
# fake                       -0.637315                 0.587687       -0.298793
#
#                          nums_length_fullname  name_username  \
# profile_pic                         -0.131756      -0.124903
# nums_length_of_username              0.408567       0.056890
# fullname_words                      -0.094348      -0.082969
# nums_length_fullname                 1.000000       0.291149
# name_username                        0.291149       1.000000
# description_length                  -0.117521      -0.064814
# external_URL                        -0.088724      -0.039232
# private                             -0.030030       0.046084
# no_of_posts                         -0.057716      -0.049808
# no_of_followers                     -0.027035      -0.017761
# no_of_following                     -0.067971      -0.009529
# fake                                 0.246782       0.170695
#
#                          description_length  external_URL   private  \
# profile_pic                        0.367892      0.236729  0.114732
# nums_length_of_username           -0.321170     -0.237125 -0.063713
# fullname_words                     0.272522      0.196562 -0.089070
# nums_length_fullname              -0.117521     -0.088724 -0.030030
# name_username                     -0.064814     -0.039232  0.046084
# description_length                 1.000000      0.482313 -0.110329
# external_URL                       0.482313      1.000000 -0.162612
# private                           -0.110329     -0.162612  1.000000
# no_of_posts                        0.144824      0.165008 -0.087495
# no_of_followers                    0.005929      0.027189 -0.073473
# no_of_following                    0.226561      0.142519 -0.057542
# fake                              -0.460825     -0.362809 -0.028586
#
#                          no_of_posts  no_of_followers  no_of_following  \
# profile_pic                 0.169570         0.061137         0.194833
# nums_length_of_username    -0.157442        -0.062785        -0.172413
# fullname_words              0.073350         0.033225         0.094855
# nums_length_fullname       -0.057716        -0.027035        -0.067971
# name_username              -0.049808        -0.017761        -0.009529
# description_length          0.144824         0.005929         0.226561
# external_URL                0.165008         0.027189         0.142519
# private                    -0.087495        -0.073473        -0.057542
# no_of_posts                 1.000000         0.321385         0.098225
# no_of_followers             0.321385         1.000000        -0.011066
# no_of_following             0.098225        -0.011066         1.000000
# fake                       -0.245355        -0.093689        -0.224835
#
#                              fake
# profile_pic             -0.637315
# nums_length_of_username  0.587687
# fullname_words          -0.298793
# nums_length_fullname     0.246782
# name_username            0.170695
# description_length      -0.460825
# external_URL            -0.362809
# private                 -0.028586
# no_of_posts             -0.245355
# no_of_followers         -0.093689
# no_of_following         -0.224835
# fake                     1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap='Reds')
# Out:
# <Axes: >

# %%
fake_high_chance=df[df["fake"]>=0.8]
fake_high_chance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 288 entries, 288 to 575
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   profile_pic              288 non-null    int64
#  1   nums_length_of_username  288 non-null    float64
#  2   fullname_words           288 non-null    int64
#  3   nums_length_fullname     288 non-null    float64
#  4   name_username            288 non-null    int64
#  5   description_length       288 non-null    int64
#  6   external_URL             288 non-null    int64
#  7   private                  288 non-null    int64
#  8   no_of_posts              288 non-null    int64
#  9   no_of_followers          288 non-null    int64
#  10  no_of_following          288 non-null    int64
#  11  fake                     288 non-null    int64
# dtypes: float64(2), int64(10)
# memory usage: 29.2 KB

# %%
fake_high_chance.corr()
# Out:
#                          profile_pic  nums_length_of_username  fullname_words  \
# profile_pic                 1.000000                 0.015879        0.039562
# nums_length_of_username     0.015879                 1.000000       -0.129303
# fullname_words              0.039562                -0.129303        1.000000
# nums_length_fullname        0.034925                 0.353915       -0.038557
# name_username              -0.022320                -0.057699       -0.057276
# description_length          0.243207                -0.143506        0.080014
# external_URL                     NaN                      NaN             NaN
# private                     0.198655                -0.068524       -0.207029
# no_of_posts                 0.286045                 0.022038        0.107682
# no_of_followers             0.042088                -0.089803        0.042850
# no_of_following             0.124544                -0.093809        0.037859
# fake                             NaN                      NaN             NaN
#
#                          nums_length_fullname  name_username  \
# profile_pic                          0.034925      -0.022320
# nums_length_of_username              0.353915      -0.057699
# fullname_words                      -0.038557      -0.057276
# nums_length_fullname                 1.000000       0.273916
# name_username                        0.273916       1.000000
# description_length                  -0.045951       0.010347
# external_URL                              NaN            NaN
# private                             -0.028991       0.058208
# no_of_posts                          0.030746      -0.072412
# no_of_followers                     -0.062720       0.036651
# no_of_following                     -0.035898       0.067527
# fake                                      NaN            NaN
#
#                          description_length  external_URL   private  \
# profile_pic                        0.243207           NaN  0.198655
# nums_length_of_username           -0.143506           NaN -0.068524
# fullname_words                     0.080014           NaN -0.207029
# nums_length_fullname              -0.045951           NaN -0.028991
# name_username                      0.010347           NaN  0.058208
# description_length                 1.000000           NaN  0.033770
# external_URL                            NaN           NaN       NaN
# private                            0.033770           NaN  1.000000
# no_of_posts                        0.080788           NaN  0.123337
# no_of_followers                    0.121675           NaN -0.094753
# no_of_following                    0.051611           NaN -0.056738
# fake                                    NaN           NaN       NaN
#
#                          no_of_posts  no_of_followers  no_of_following  fake
# profile_pic                 0.286045         0.042088         0.124544   NaN
# nums_length_of_username     0.022038        -0.089803        -0.093809   NaN
# fullname_words              0.107682         0.042850         0.037859   NaN
# nums_length_fullname        0.030746        -0.062720        -0.035898   NaN
# name_username              -0.072412         0.036651         0.067527   NaN
# description_length          0.080788         0.121675         0.051611   NaN
# external_URL                     NaN              NaN              NaN   NaN
# private                     0.123337        -0.094753        -0.056738   NaN
# no_of_posts                 1.000000         0.072308         0.188808   NaN
# no_of_followers             0.072308         1.000000         0.605396   NaN
# no_of_following             0.188808         0.605396         1.000000   NaN
# fake                             NaN              NaN              NaN   NaN

# %%
X=df["nums_length_fullname"].values
X=X/0.04
y=df["fake"].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
lr =LinearRegression()

# %%
lr.fit(X_train.reshape(-1,1), y_train)
y_pred=lr.predict(X_test.reshape(-1,1))

# %%
lr.score (X_test.reshape(-1,1),y_test.reshape(-1,1))
# Out:
# 0.08260445729968069

# %%
#test input
test=0.038
val=test/0.038
val_out=lr.predict(np.array([[val]]))
print("Probability that the account is fake: ",val_out[0])
# Out:
# Probability that the account is fake:  0.5084412634326482

# %%
#creating a model on entire data
X=df.drop(['fake'],axis=1)
y=df['fake']
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.2, random_state = 8)

# %%
#random forest regression
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=2, random_state=0, n_estimators=5)
regr.fit(X_train,y_train)
regr.score(X_test, y_test)
# Out:
# 0.7554082302456215

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=2, random_state=0, n_estimators=5)
clf.fit(X_train,y_train)
data = ([[1,0.0,1,0.0,0,8,0,1,11,672,689]])
prediction = clf.predict(data)
if prediction[0] == 0:
  print("Predicted class: Not Fake")
elif prediction[0] == 1:
  print("Predicted class: Fake")
else:
  print("Unexpected prediction value")
# Out:
# Predicted class: Not Fake
# C:\Users\Nameet\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
model_rf = RandomForestRegressor(random_state=1)
model_rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=1)

# %%
y_pred_rf=model_rf.predict(X_test)
y_pred_rf = [1 if each > 0.75 else 0 for each in y_pred_rf]

# %%
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score
from sklearn.metrics import classification_report

# %%
ConfusionMatrixDisplay.from_predictions(y_test,y_pred_rf)
plt.title('Random Forest')
plt.show()
print(f" Accuracy is {accuracy_score(y_test,y_pred_rf)}")
print(classification_report(y_test,y_pred_rf))
# Out:
#  Accuracy is 0.9568965517241379
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        63
#            1       1.00      0.91      0.95        53
#
#     accuracy                           0.96       116
#    macro avg       0.96      0.95      0.96       116
# weighted avg       0.96      0.96      0.96       116
